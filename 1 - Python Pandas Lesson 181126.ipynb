# %% [markdown]
# # Pandas Lesson Plan
# ## 11/26/2018
# - ideas
#     - import this
#     - byod
#         - troubleshoot specific projects
#     - setup mybinder instance for class
#         - how to save that?
#     - icon relationship
#         - excel, numpy, sklearn, geopandas, R, stackoverflow and documentation
# - exercises
# - specifics to highlight:
#     - import data
#     - save data
#     - save figure
# ## Resources
# - [Working through Chronic Disease Dataset](https://healthcare.ai/we-heart-pandas/)
# - [CDC Dataset](https://healthdata.gov/dataset/us-chronic-disease-indicators-cdi)
# - [CDC Dictionary for Dataset](https://chronicdata.cdc.gov/Chronic-Disease-Indicators/U-S-Chronic-Disease-Indicators-CDI-/g4ie-h725)

# %%
## outline
- quick overview how things work
    - python syntax
        - object
        - functions
        - attributes
        - comments
    - jupyter notebooks
    - what is pandas
    - objects and attributes
- importing data
    - read_csv
    - read_excel
- cleaning data
    - .head()
    - .shape
    - .columns
    - select by value
    - value_counts()
    - unique()
    - nunique()
- examine data
    - info()
    - describe()
    - plot()
        - paired bar (male and female)
        - location by states
- exercise: extend this to a different question
    - value of recycling code

# %%
import pandas as pd

# %%
# import the data we'll be using
# note that the path to the data is relative to the Jupyter notebook location

df = pd.read_csv('data/diabetes.csv')
# Out:
# /Users/chambersmj/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (8,11,19,20,21,22,24,31,32,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#        Unnamed: 0  YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0           14270       2016     2016           HI                Hawaii
# 1           14313       2016     2016           ID                 Idaho
# 2           14496       2016     2016           IL              Illinois
# 3           14742       2016     2016           MN             Minnesota
# 4           15133       2016     2016           GU                  Guam
# 5           15326       2016     2016           IN               Indiana
# 6           15792       2016     2016           IA                  Iowa
# 7           15821       2016     2016           PR           Puerto Rico
# 8           16097       2016     2016           KS                Kansas
# 9           16178       2016     2016           GU                  Guam
# 10          16435       2016     2016           DC  District of Columbia
# 11          16510       2016     2016           KY              Kentucky
# ...

# %%
df['Question'].unique().tolist()
# Out:
# ['Diabetes prevalence among women aged 18-44 years',
#  'Prevalence of depressive disorders among adults aged >= 18 years with diagnosed diabetes',
#  'Prevalence of diagnosed diabetes among adults aged >= 18 years',
#  'Adults with diagnosed diabetes aged >= 18 years who have taken a diabetes self-management course',
#  'Influenza vaccination among noninstitutionalized adults aged 18-64 years with diagnosed diabetes',
#  'Influenza vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes',
#  'Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with diagnosed diabetes',
#  'Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes',
#  'Foot examination among adults aged >= 18 years with diagnosed diabetes',
#  'Glycosylated hemoglobin measurement among adults aged >= 18 years with diagnosed diabetes',
#  'Dilated eye examination among adults aged >= 18 years with diagnosed diabetes',
# ...

# %%
# so what can we do with this "df" data object that we just created?

df. # place cursor after "." and hit "tab" to view options

# %%
# what do all these things do?

 # use "?" after any attribute or function to view the documentation?
df.head?

# %%
# checak out what it looks like using the ".head()" function
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource    Topic  \
# 0       2016     2016           US  United States      BRFSS  Alcohol
# 1       2016     2016           AL        Alabama      BRFSS  Alcohol
# 2       2016     2016           AK         Alaska      BRFSS  Alcohol
# 3       2016     2016           AZ        Arizona      BRFSS  Alcohol
# 4       2016     2016           AR       Arkansas      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      NaN             %
# 1  Binge drinking prevalence among adults aged >=...      NaN             %
# 2  Binge drinking prevalence among adults aged >=...      NaN             %
# 3  Binge drinking prevalence among adults aged >=...      NaN             %
# 4  Binge drinking prevalence among adults aged >=...      NaN             %
#
#       DataValueType        ...        LocationID  TopicID QuestionID  \
# ...

# %%
df.columns.tolist()
# Out:
# ['YearStart',
#  'YearEnd',
#  'LocationAbbr',
#  'LocationDesc',
#  'DataSource',
#  'Topic',
#  'Question',
#  'Response',
#  'DataValueUnit',
#  'DataValueType',
#  'DataValue',
#  'DataValueAlt',
#  'DataValueFootnoteSymbol',
#  'DatavalueFootnote',
#  'LowConfidenceLimit',
#  'HighConfidenceLimit',
#  'StratificationCategory1',
#  'Stratification1',
#  'StratificationCategory2',
#  'Stratification2',
#  'StratificationCategory3',
#  'Stratification3',
#  'GeoLocation',
#  'ResponseID',
#  'LocationID',
#  'TopicID',
#  'QuestionID',
#  'DataValueTypeID',
#  'StratificationCategoryID1',
#  'StratificationID1',
#  'StratificationCategoryID2',
#  'StratificationID2',
#  'StratificationCategoryID3',
#  'StratificationID3']

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource    Topic  \
# 0       2016     2016           US  United States      BRFSS  Alcohol
# 1       2016     2016           AL        Alabama      BRFSS  Alcohol
# 2       2016     2016           AK         Alaska      BRFSS  Alcohol
# 3       2016     2016           AZ        Arizona      BRFSS  Alcohol
# 4       2016     2016           AR       Arkansas      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      NaN             %
# 1  Binge drinking prevalence among adults aged >=...      NaN             %
# 2  Binge drinking prevalence among adults aged >=...      NaN             %
# 3  Binge drinking prevalence among adults aged >=...      NaN             %
# 4  Binge drinking prevalence among adults aged >=...      NaN             %
#
#       DataValueType        ...        LocationID  TopicID QuestionID  \
# ...

# %%
df['Topic'].unique()
# Out:
# array(['Alcohol', 'Arthritis', 'Asthma', 'Cancer', 'Diabetes',
#        'Mental Health', 'Chronic Obstructive Pulmonary Disease',
#        'Oral Health', 'Cardiovascular Disease', 'Immunization',
#        'Chronic Kidney Disease',
#        'Nutrition, Physical Activity, and Weight Status', 'Older Adults',
#        'Tobacco', 'Overarching Conditions', 'Reproductive Health',
#        'Disability'], dtype=object)

# %%
pd.DataFrame(df.groupby('Topic')['Question'].value_counts())
# Out:
#                                                                            Question
# Topic                  Question
# Alcohol                Chronic liver disease mortality                         6135
#                        Binge drinking frequency among adults aged >= 1...      5220
#                        Binge drinking intensity among adults aged >= 1...      5220
#                        Binge drinking prevalence among adults aged >= ...      5220
#                        Heavy drinking among adults aged >= 18 years            5220
#                        Binge drinking prevalence among women aged 18-4...      1950
#                        Heavy drinking among women aged 18-44 years             1950
#                        Alcohol use among youth                                  110
#                        Amount of alcohol excise tax by beverage type (...       110
#                        Amount of alcohol excise tax by beverage type (...       110
# ...

# %%
df[df['Topic'] == 'Diabetes']['Question'].unique().tolist()
# Out:
# ['Diabetes prevalence among women aged 18-44 years',
#  'Prevalence of depressive disorders among adults aged >= 18 years with diagnosed diabetes',
#  'Prevalence of diagnosed diabetes among adults aged >= 18 years',
#  'Adults with diagnosed diabetes aged >= 18 years who have taken a diabetes self-management course',
#  'Influenza vaccination among noninstitutionalized adults aged 18-64 years with diagnosed diabetes',
#  'Influenza vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes',
#  'Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with diagnosed diabetes',
#  'Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes',
#  'Foot examination among adults aged >= 18 years with diagnosed diabetes',
#  'Glycosylated hemoglobin measurement among adults aged >= 18 years with diagnosed diabetes',
#  'Dilated eye examination among adults aged >= 18 years with diagnosed diabetes',
# ...

# %%
questions = df['Question'].value_counts()

# %%
q_df = pd.DataFrame(questions)

# %%
q_df
# Out:
#                                                     Question
# Hospitalization for heart failure among Medicar...      7488
# Hospitalization for hip fracture among Medicare...      7488
# Hospitalization for chronic obstructive pulmona...      7488
# Hospitalization for chronic obstructive pulmona...      7488
# Asthma mortality rate                                   6135
# Mortality due to diabetes reported as any liste...      6135
# Mortality from total cardiovascular diseases            6135
# Premature mortality among adults aged 45-64 years       6135
# Mortality from diseases of the heart                    6135
# Mortality from coronary heart disease                   6135
# Mortality with chronic obstructive pulmonary di...      6135
# Mortality with end-stage renal disease                  6135
# Mortality from heart failure                            6135
# Mortality with chronic obstructive pulmonary di...      6135
# ...

# %%
new_df = df[df['Question'] == 'Mortality due to diabetes reported as any listed cause of death']

# %%
new_df.head()
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource     Topic  \
# 292677       2014     2014           AK       Alaska       NVSS  Diabetes
# 292678       2014     2014           AK       Alaska       NVSS  Diabetes
# 292679       2014     2014           AK       Alaska       NVSS  Diabetes
# 292680       2014     2014           AK       Alaska       NVSS  Diabetes
# 292681       2014     2014           AK       Alaska       NVSS  Diabetes
#
#                                                  Question Response  \
# 292677  Mortality due to diabetes reported as any list...
# 292678  Mortality due to diabetes reported as any list...
# 292679  Mortality due to diabetes reported as any list...
# 292680  Mortality due to diabetes reported as any list...
# 292681  Mortality due to diabetes reported as any list...
#
#             DataValueUnit      DataValueType        ...        LocationID  \
# 292677  cases per 100,000  Age-adjusted Rate        ...                 2
# ...

# %%
alaska_2014 = new_df[(new_df['YearStart'] == 2014) & (new_df['LocationDesc'] == 'Alaska')]

# %%
alaska_2014.shape
# Out:
# (24, 34)

# %%
alaska_2014['Stratification1'].nunique()
# Out:
# 8

# %%
alaska_2014[['DataValueType', 'DataValue', 'StratificationCategoryID1', 'Stratification1']]
# Out:
#             DataValueType DataValue StratificationCategoryID1  \
# 292677  Age-adjusted Rate      59.8                      RACE
# 292678  Age-adjusted Rate      85.1                      RACE
# 292679  Age-adjusted Rate                                RACE
# 292680  Age-adjusted Rate      48.6                    GENDER
# 292681  Age-adjusted Rate                                RACE
# 292682  Age-adjusted Rate      70.4                    GENDER
# 292683  Age-adjusted Rate      59.3                   OVERALL
# 292684  Age-adjusted Rate      54.4                      RACE
# 293087         Crude Rate      36.8                      RACE
# 293088         Crude Rate      51.1                      RACE
# 293089         Crude Rate                                RACE
# 293090         Crude Rate      38.6                    GENDER
# 293091         Crude Rate                                RACE
# 293092         Crude Rate      51.3                    GENDER
# ...

# %%
# keep only age adjusted values
alaska_2014[alaska_2014['DataValueType'] == 'Age-adjusted Rate'].shape
# Out:
# (8, 34)

# %%
alaska_2014.nunique()
# Out:
# YearStart                     1
# YearEnd                       1
# LocationAbbr                  1
# LocationDesc                  1
# DataSource                    1
# Topic                         1
# Question                      1
# Response                      1
# DataValueUnit                 1
# DataValueType                 3
# DataValue                    19
# DataValueAlt                 18
# DataValueFootnoteSymbol       2
# DatavalueFootnote             2
# LowConfidenceLimit           12
# HighConfidenceLimit          12
# StratificationCategory1       3
# Stratification1               8
# StratificationCategory2       1
# Stratification2               1
# StratificationCategory3       1
# Stratification3               1
# GeoLocation                   1
# ResponseID                    1
# LocationID                    1
# TopicID                       1
# QuestionID                    1
# DataValueTypeID               3
# StratificationCategoryID1     3
# ...

# %%
new_df[['DataValueUnit', 'DataValueType', 'DataValue', 'DataValueAlt']]
# Out:
#             DataValueUnit      DataValueType DataValue  DataValueAlt
# 292677  cases per 100,000  Age-adjusted Rate      59.8          59.8
# 292678  cases per 100,000  Age-adjusted Rate      85.1          85.1
# 292679  cases per 100,000  Age-adjusted Rate                     NaN
# 292680  cases per 100,000  Age-adjusted Rate      48.6          48.6
# 292681  cases per 100,000  Age-adjusted Rate                     NaN
# 292682  cases per 100,000  Age-adjusted Rate      70.4          70.4
# 292683  cases per 100,000  Age-adjusted Rate      59.3          59.3
# 292684  cases per 100,000  Age-adjusted Rate      54.4          54.4
# 292685  cases per 100,000  Age-adjusted Rate                     NaN
# 292686  cases per 100,000  Age-adjusted Rate                     NaN
# 292687  cases per 100,000  Age-adjusted Rate      96.5          96.5
# 292688  cases per 100,000  Age-adjusted Rate      49.8          49.8
# 292689  cases per 100,000  Age-adjusted Rate        26          26.0
# ...

# %%
new_df['Stratification1'].unique()
# Out:
# array(['American Indian or Alaska Native', 'Asian or Pacific Islander',
#        'Black, non-Hispanic', 'Female', 'Hispanic', 'Male', 'Overall',
#        'White, non-Hispanic'], dtype=object)

# %%
new_df.nunique()
# Out:
# YearStart                       5
# YearEnd                         5
# LocationAbbr                   52
# LocationDesc                   52
# DataSource                      1
# Topic                           1
# Question                        1
# Response                        1
# DataValueUnit                   1
# DataValueType                   3
# DataValue                    2333
# DataValueAlt                 2332
# DataValueFootnoteSymbol         2
# DatavalueFootnote               2
# LowConfidenceLimit           1123
# HighConfidenceLimit          1260
# StratificationCategory1         3
# Stratification1                 8
# StratificationCategory2         1
# Stratification2                 1
# StratificationCategory3         1
# Stratification3                 1
# GeoLocation                    51
# ResponseID                      1
# LocationID                     52
# TopicID                         1
# QuestionID                      1
# ...

# %%
# extra stuff

# %%
# import the original CDC dataset (large file)
df = pd.read_csv('data/U.S._Chronic_Disease_Indicators__CDI_.csv')

# save main dataset to multiple files
for topic,group_df in df.groupby(pd.Grouper(key='Topic')):
    name = f'data/{topic.lower()}.csv'
    group_df.to_csv(name)
