# %% [markdown]
# # Data Analysis with Python and Pandas
# ## Michael Chambers - Nov. 26th, 2018
# **Goal**: Exposure to Python and Pandas for Data Analysis
#
# **Objectives**:
# - Overview of basic Python syntax and how to use Jupyter Notebooks (will be used in both lessons for the day)
# - Work through a basic workflow using a CDC dataset (load, clean, manipulate, visualize, save)
# - Exercise: apply the same workflow to a different question in the CDC dataset
#
# **Recommended Prior Reading Assignment**: [Intro to Pandas for Excel Super Users – Joan Wang](https://towardsdatascience.com/intro-to-pandas-for-excel-super-users-dac1b38f12b0)
#
# Additional Resources:
# - [Download Anaconda](https://www.anaconda.com/download/#macos)
# - [Python DataScience Handbook – Jake VanderPlas](https://github.com/jakevdp/PythonDataScienceHandbook)
# - [Reproducible Data Analysis Videos – Jake VanderPlas](https://www.youtube.com/watch?v=_ZEWDGpM-vM&list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ)
# - [19 Essential Snippets in Pandas – Jeff Delaney](https://jeffdelaney.me/blog/useful-snippets-in-pandas/)
# - [Merge and Join DataFrames with Pandas in Python – Shane Lynn](https://www.shanelynn.ie/merge-join-dataframes-python-pandas-index-1/)
#
# ## TODO:
# - figure at top
# - hw questions
# - wrap-up environment dependencies
#     - make sure it works for students
# - adding in exercises, easy to follow
# - duplicate notebook for in-class demo
# - choropleth (interactive with Plotly?)
#
# ## Resources
# - [Working through Chronic Disease Dataset](https://healthcare.ai/we-heart-pandas/)
# - [CDC Dataset](https://healthdata.gov/dataset/us-chronic-disease-indicators-cdi)
# - [CDC Dictionary for Dataset](https://chronicdata.cdc.gov/Chronic-Disease-Indicators/U-S-Chronic-Disease-Indicators-CDI-/g4ie-h725)

# %%
# show example image of data at top

# %% [markdown]
# # Python 🐍
# ![xkdc](https://imgs.xkcd.com/comics/python.png)

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # Jupyter Notebooks 📓
# ---
# * Incredible resource and tool for data science
# * Offers a reproducible environment that tells a story
# * It's also a great sandbox environment to learn Python

# %% [markdown]
# ### A quick note about cell types in Jupyter

# %% [markdown]
# print('this is not a coding cell')

# %%
print('this is a coding cell')
# Out:
# this is a coding cell

# %%
# run a code cell
2 + 2
# Out:
# 4

# %%
# we can create a variable called "x"
x = 2 + 2

# %%
# that variable refers to the object we set it to
x
# Out:
# 4

# %%
# we can use functions to manipulate our objects
# "print()" is a built-in python function
print(x)
# Out:
# 4

# %% [markdown]
# ### Supercharging Python with Packages
# As soon as you start up a python session you instantly have access to [~70 functions](https://docs.python.org/3/library/functions.html).  If we want to do something specific with our object that goes beyone the scope of the built-in functions we are presented with three options:
# 1. Sit and cry
# 2. Define our own functions (that's a bit out of scope for this lesson)
# 3. Use packages!
#
# **Packages** (or libraries) are collections of functions that other folks have already written.  This is a huge component of why python is an incredible programing language, chances are someone's already written something that you can use.
#
# Before we can start using functions provided by packages we first have to import the package.

# %% [markdown]
# # Pandas 🐼
# ---
# ### [Legend has it...](https://qz.com/1126615/the-story-of-the-most-important-tool-in-data-science/)
#
# Pandas was develped by Wes McKinney (from Akron, Ohio!!!). Math guy from MIT that went into finance, found that the problem with hedge fund management was dealing with the data (sourcing new data, merging it with the old, and cleaning it all up to optimize the input). He got bummed out with Excel and R but was smitten with Python, though he realized there was no robust package for data analysis. So he built Pandas in 2008 and released the project to the public in 2009.
#
# Here's where it get's crazy, he left the world if finance to pursue a PhD in statistics at Duke, thus dropping Pandas development. During that period he realized Python as a language could explode as a statistical computing language, it had the potential, but was still missing robust packages. So he dropped out to push Pandas to become the a cornerstone of the Python scientific ecosystem.
#
# And he put all his tips and tricks for Pandas into a book: Python for [Data Data Analysis](https://github.com/wesm/pydata-book)
#
# ### What is Pandas?
#
# "[Pandas] enables people to analyze and work with data who are not expert computer scientists. You still have to write code, but it's making the code intuitive and accessible. It helps people move beyond just using Excel for data analysis." ~Wes
#
# - The go-to data analysis library for Python
#     - Import and wrangle your raw data
#     - Manipulate and visualize
# - Allows for mixed data types in the same array
#
# The DataFrame is your friend!
#
# - Two primary object types used in Pandas:
#     - DataFrames - like an Excel spreadsheet
#     - Series - like a single column in a spreadsheet
# - DataFrames are the primary object used in Pandas (it's like an Excel sheet)
# - Each DataFrame has:
#     - columns: the variables being measured
#     - rows: the observations being made
#     - index: maintains the order of the rows

# %%
# how to import a package 
# note: "pd" is an abbreviation that allows us to access the functions provided in the package
# you will find that many popular python packages have conventional abbreviations when imported
import pandas as pd

# %% [markdown]
# ### Our dataset...
# We'll be examining some CDC influznea surveillence data from 2008-2018, which was sourced from the [CDC FluView website](https://gis.cdc.gov/grasp/fluview/fluportaldashboard.html).  What we're interested in are the influenza-like-illness cases per week ("ILITOTAL").

# %%
# import the data we'll be using
# note: the path to the data is relative to the Jupyter notebook location
df = pd.read_csv('data/ILINet.csv')

# %%
# there are a few functions we can use to quickly get a feel for the dataset
# the "head()" function will show us the first 5 rows of our dataframe
df.head()
# Out:
#   REGION TYPE      REGION  YEAR  WEEK % WEIGHTED ILI %UNWEIGHTED ILI AGE 0-4  \
# 0      States     Alabama  2014    40              X         1.73174       X
# 1      States      Alaska  2014    40              X        0.437445       X
# 2      States     Arizona  2014    40              X         1.02937       X
# 3      States    Arkansas  2014    40              X         1.07239       X
# 4      States  California  2014    40              X          1.9089       X
#
#   AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65 ILITOTAL NUM. OF PROVIDERS  \
# 0         X         X        X         X      X      220                26
# 1         X         X        X         X      X        5                 7
# 2         X         X        X         X      X      299                59
# 3         X         X        X         X      X       48                17
# 4         X         X        X         X      X      831               129
#
#   TOTAL PATIENTS
# 0          12704
# 1           1143
# 2          29047
# 3           4476
# 4          43533

# %% [markdown]
# ### Some functions to try:
# ```
# df.shape
# df.info()
# df.describe()
# df.columns
# df.head()
# df.tail()
# df.sample(10)
# ```
# Note: some of these commands end with a parenthesis, others do not.  Those without parenthesis are attributes of the object, those with parenthesis are a function.

# %%
# scratch space

# %%
df.shape
# Out:
# (11610, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11610 entries, 0 to 11609
# Data columns (total 15 columns):
# REGION TYPE          11610 non-null object
# REGION               11610 non-null object
# YEAR                 11610 non-null int64
# WEEK                 11610 non-null int64
# % WEIGHTED ILI       11610 non-null object
# %UNWEIGHTED ILI      11610 non-null object
# AGE 0-4              11610 non-null object
# AGE 25-49            11610 non-null object
# AGE 25-64            11610 non-null object
# AGE 5-24             11610 non-null object
# AGE 50-64            11610 non-null object
# AGE 65               11610 non-null object
# ILITOTAL             11610 non-null object
# NUM. OF PROVIDERS    11610 non-null object
# TOTAL PATIENTS       11610 non-null object
# dtypes: int64(2), object(13)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#                YEAR          WEEK
# count  11610.000000  11610.000000
# mean    2016.288372     27.069767
# std        1.224078     15.103084
# min     2014.000000      1.000000
# 25%     2015.000000     14.000000
# 50%     2016.000000     27.000000
# 75%     2017.000000     41.000000
# max     2018.000000     53.000000

# %%
df.columns
# Out:
# Index(['REGION TYPE', 'REGION', 'YEAR', 'WEEK', '% WEIGHTED ILI',
#        '%UNWEIGHTED ILI', 'AGE 0-4', 'AGE 25-49', 'AGE 25-64', 'AGE 5-24',
#        'AGE 50-64', 'AGE 65', 'ILITOTAL', 'NUM. OF PROVIDERS',
#        'TOTAL PATIENTS'],
#       dtype='object')

# %%
df.head()
# Out:
#   REGION TYPE      REGION  YEAR  WEEK % WEIGHTED ILI %UNWEIGHTED ILI AGE 0-4  \
# 0      States     Alabama  2014    40              X         1.73174       X
# 1      States      Alaska  2014    40              X        0.437445       X
# 2      States     Arizona  2014    40              X         1.02937       X
# 3      States    Arkansas  2014    40              X         1.07239       X
# 4      States  California  2014    40              X          1.9089       X
#
#   AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65 ILITOTAL NUM. OF PROVIDERS  \
# 0         X         X        X         X      X      220                26
# 1         X         X        X         X      X        5                 7
# 2         X         X        X         X      X      299                59
# 3         X         X        X         X      X       48                17
# 4         X         X        X         X      X      831               129
#
#   TOTAL PATIENTS
# 0          12704
# 1           1143
# 2          29047
# 3           4476
# 4          43533

# %%
df.tail()
# Out:
#       REGION TYPE          REGION  YEAR  WEEK % WEIGHTED ILI %UNWEIGHTED ILI  \
# 11605      States       Wisconsin  2018    45              X         1.22503
# 11606      States         Wyoming  2018    45              X        0.797401
# 11607      States     Puerto Rico  2018    45              X         8.38926
# 11608      States  Virgin Islands  2018    45              X        0.788436
# 11609      States   New York City  2018    45              X         2.36452
#
#       AGE 0-4 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65 ILITOTAL  \
# 11605       X         X         X        X         X      X      214
# 11606       X         X         X        X         X      X       27
# 11607       X         X         X        X         X      X      150
# 11608       X         X         X        X         X      X        6
# 11609       X         X         X        X         X      X     2155
#
#       NUM. OF PROVIDERS TOTAL PATIENTS
# 11605                36          17469
# 11606                17           3386
# 11607                 3           1788
# 11608                 3            761
# 11609                67          91139

# %%
df.sample(10)
# Out:
#       REGION TYPE          REGION  YEAR  WEEK % WEIGHTED ILI %UNWEIGHTED ILI  \
# 2321       States   New York City  2015    29              X        0.983771
# 2320       States  Virgin Islands  2015    29              X        0.550964
# 5879       States      Washington  2016    43              X         0.43225
# 6809       States        Colorado  2017     9              X         1.73661
# 1384       States    North Dakota  2015    12              X         1.09785
# 4889       States   New Hampshire  2016    25              X        0.187477
# 5937       States     Puerto Rico  2016    44              X         5.99241
# 4186       States          Nevada  2016    12              X         1.27855
# 5350       States      California  2016    34              X         1.04709
# 10617      States  North Carolina  2018    27              X        0.426487
#
#       AGE 0-4 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65 ILITOTAL  \
# 2321        X         X         X        X         X      X      942
# 2320        X         X         X        X         X      X        2
# 5879        X         X         X        X         X      X       23
# 6809        X         X         X        X         X      X       60
# 1384        X         X         X        X         X      X       23
# 4889        X         X         X        X         X      X        5
# 5937        X         X         X        X         X      X      221
# 4186        X         X         X        X         X      X      150
# 5350        X         X         X        X         X      X      342
# 10617       X         X         X        X         X      X       19
#
#       NUM. OF PROVIDERS TOTAL PATIENTS
# 2321                 83          95754
# 2320                  1            363
# 5879                 47           5321
# 6809                  5           3455
# 1384                  9           2095
# 4889                 16           2667
# 5937                  7           3688
# 4186                 24          11732
# 5350                 81          32662
# 10617                21           4455

# %% [markdown]
# ### Quick Exercise
# - How many entries of data do we have (number of observations)?
# - How many columns do we have (number of variables)?
# - Any first impression on what we may have to clean in this dataset?

# %%
# scratch space

# %%
df.shape
# Out:
# (11610, 15)

# %%
len(df)
# Out:
# 11610

# %%
len(df.columns)
# Out:
# 15

# %%
len(df.index)
# Out:
# 11610

# %% [markdown]
# ### Basic Data Cleanup
# For now lets narrow down this dataset to some simple components:
# - REGION
# - YEAR
# - WEEK
# - ILITOTAL

# %%
# we'll select just those columns and create new dataframe
df1 = df[['YEAR', 'WEEK','REGION','ILITOTAL']]

# %%
# let's check the summary of our new dataframe using the "info()" function
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11610 entries, 0 to 11609
# Data columns (total 4 columns):
# YEAR        11610 non-null int64
# WEEK        11610 non-null int64
# REGION      11610 non-null object
# ILITOTAL    11610 non-null object
# dtypes: int64(2), object(2)
# memory usage: 362.9+ KB

# %% [markdown]
# Note that our "ILITOTAL" variable is an 'object' type, not an integer ('int64').  This means that there are some string values in this column that we should clean up.

# %%
# let's take a closer look at our new dataframe
df1.head(10)
# Out:
#    YEAR  WEEK                REGION ILITOTAL
# 0  2014    40               Alabama      220
# 1  2014    40                Alaska        5
# 2  2014    40               Arizona      299
# 3  2014    40              Arkansas       48
# 4  2014    40            California      831
# 5  2014    40              Colorado       19
# 6  2014    40           Connecticut       60
# 7  2014    40              Delaware        1
# 8  2014    40  District of Columbia      119
# 9  2014    40               Florida        X

# %%
# note that in row 9 we have a value of "X" for 'ILITOTAL'
# lets replace all the "X" values in 'ILITOTAL' with a null placeholder
# to do this we're going to import another pachage called NumPy
import numpy as np
df1['ILITOTAL'].replace('X', np.nan, inplace=True)
# Out:
# /Users/chambersmj/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5886: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
# and we'll check the top 10 lines to see if "X" was replaced
df1.head(10)
# Out:
#    YEAR  WEEK                REGION ILITOTAL
# 0  2014    40               Alabama      220
# 1  2014    40                Alaska        5
# 2  2014    40               Arizona      299
# 3  2014    40              Arkansas       48
# 4  2014    40            California      831
# 5  2014    40              Colorado       19
# 6  2014    40           Connecticut       60
# 7  2014    40              Delaware        1
# 8  2014    40  District of Columbia      119
# 9  2014    40               Florida      NaN

# %%
# but what about the column type?
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11610 entries, 0 to 11609
# Data columns (total 4 columns):
# YEAR        11610 non-null int64
# WEEK        11610 non-null int64
# REGION      11610 non-null object
# ILITOTAL    11395 non-null object
# dtypes: int64(2), object(2)
# memory usage: 362.9+ KB

# %%
df1['ILITOTAL'] = df1['ILITOTAL'].astype('float')
# Out:
# /Users/chambersmj/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# now lets recheck the info for our dataframe
# note: 'ILITOTAL' is now a float object ('float64')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11610 entries, 0 to 11609
# Data columns (total 4 columns):
# YEAR        11610 non-null int64
# WEEK        11610 non-null int64
# REGION      11610 non-null object
# ILITOTAL    11395 non-null float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 362.9+ KB

# %%
# lets try the "describe()" function again
# note: we now have summary states for 'ILITOTAL'
df1.describe()
# Out:
#                YEAR          WEEK      ILITOTAL
# count  11610.000000  11610.000000  11395.000000
# mean    2016.288372     27.069767    314.264941
# std        1.224078     15.103084    657.111692
# min     2014.000000      1.000000      0.000000
# 25%     2015.000000     14.000000     21.000000
# 50%     2016.000000     27.000000     93.000000
# 75%     2017.000000     41.000000    309.000000
# max     2018.000000     53.000000  11452.000000

# %%
# one more safetey check, is this just for the 50 US states?
df1['REGION'].nunique()
# Out:
# 54

# %%
df1['REGION'].unique().tolist()
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming',
#  'Puerto Rico',
#  'Virgin Islands',
#  'New York City']

# %%
# we'll create of list of the regions we'd like to remove
remove_regions = ['Puerto Rico', 'Virgin Islands', 'New York City']

# %%
# now we'll select all the rows that do not include the regions in 'remove_regions'
# note: what happens if you remove the "~"?
df2 = df1[~df1['REGION'].isin(remove_regions)]

# %%
df2.head()
# Out:
#    YEAR  WEEK      REGION  ILITOTAL
# 0  2014    40     Alabama     220.0
# 1  2014    40      Alaska       5.0
# 2  2014    40     Arizona     299.0
# 3  2014    40    Arkansas      48.0
# 4  2014    40  California     831.0

# %% [markdown]
# ### Working with time series
# Pandas can be very helpful when trying to organize time-series data.  This is going to get a bit hairy, but we're going to parse down our data even further by lumping our "YEAR" and "WEEK" data into a single variable.

# %%
# this is a pretty dense line
# we're combining the information from the "YEAR" and "WEEK" columns to create a time-series value
# we'll be using the new time-series values to manipulate our dataframe
df2['date'] = pd.to_datetime(df2.YEAR.astype(str), format='%Y') + \
             pd.to_timedelta(df2.WEEK.mul(7).astype(str) + ' days')
# Out:
# /Users/chambersmj/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# we can check for our new column
df2.head()
# Out:
#    YEAR  WEEK      REGION  ILITOTAL       date
# 0  2014    40     Alabama     220.0 2014-10-08
# 1  2014    40      Alaska       5.0 2014-10-08
# 2  2014    40     Arizona     299.0 2014-10-08
# 3  2014    40    Arkansas      48.0 2014-10-08
# 4  2014    40  California     831.0 2014-10-08

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10965 entries, 0 to 11606
# Data columns (total 5 columns):
# YEAR        10965 non-null int64
# WEEK        10965 non-null int64
# REGION      10965 non-null object
# ILITOTAL    10750 non-null float64
# date        10965 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 514.0+ KB

# %%
df2.set_index('date',drop=True, append=False, inplace=True)

# %% [markdown]
# ### Data Visualization
# Now that we have simplified our dataset lets make some figures!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
# %matplotlib inline

# %%
df2.groupby('REGION')['ILITOTAL'].plot()
# Out:
# REGION
# Alabama                 AxesSubplot(0.125,0.2;0.775x0.68)
# Alaska                  AxesSubplot(0.125,0.2;0.775x0.68)
# Arizona                 AxesSubplot(0.125,0.2;0.775x0.68)
# Arkansas                AxesSubplot(0.125,0.2;0.775x0.68)
# California              AxesSubplot(0.125,0.2;0.775x0.68)
# Colorado                AxesSubplot(0.125,0.2;0.775x0.68)
# Connecticut             AxesSubplot(0.125,0.2;0.775x0.68)
# Delaware                AxesSubplot(0.125,0.2;0.775x0.68)
# District of Columbia    AxesSubplot(0.125,0.2;0.775x0.68)
# Florida                 AxesSubplot(0.125,0.2;0.775x0.68)
# Georgia                 AxesSubplot(0.125,0.2;0.775x0.68)
# Hawaii                  AxesSubplot(0.125,0.2;0.775x0.68)
# Idaho                   AxesSubplot(0.125,0.2;0.775x0.68)
# Illinois                AxesSubplot(0.125,0.2;0.775x0.68)
# Indiana                 AxesSubplot(0.125,0.2;0.775x0.68)
# Iowa                    AxesSubplot(0.125,0.2;0.775x0.68)
# Kansas                  AxesSubplot(0.125,0.2;0.775x0.68)
# Kentucky                AxesSubplot(0.125,0.2;0.775x0.68)
# Louisiana               AxesSubplot(0.125,0.2;0.775x0.68)
# Maine                   AxesSubplot(0.125,0.2;0.775x0.68)
# Maryland                AxesSubplot(0.125,0.2;0.775x0.68)
# Massachusetts           AxesSubplot(0.125,0.2;0.775x0.68)
# Michigan                AxesSubplot(0.125,0.2;0.775x0.68)
# Minnesota               AxesSubplot(0.125,0.2;0.775x0.68)
# Mississippi             AxesSubplot(0.125,0.2;0.775x0.68)
# Missouri                AxesSubplot(0.125,0.2;0.775x0.68)
# Montana                 AxesSubplot(0.125,0.2;0.775x0.68)
# Nebraska                AxesSubplot(0.125,0.2;0.775x0.68)
# Nevada                  AxesSubplot(0.125,0.2;0.775x0.68)
# New Hampshire           AxesSubplot(0.125,0.2;0.775x0.68)
# New Jersey              AxesSubplot(0.125,0.2;0.775x0.68)
# New Mexico              AxesSubplot(0.125,0.2;0.775x0.68)
# New York                AxesSubplot(0.125,0.2;0.775x0.68)
# North Carolina          AxesSubplot(0.125,0.2;0.775x0.68)
# North Dakota            AxesSubplot(0.125,0.2;0.775x0.68)
# Ohio                    AxesSubplot(0.125,0.2;0.775x0.68)
# Oklahoma                AxesSubplot(0.125,0.2;0.775x0.68)
# Oregon                  AxesSubplot(0.125,0.2;0.775x0.68)
# Pennsylvania            AxesSubplot(0.125,0.2;0.775x0.68)
# Rhode Island            AxesSubplot(0.125,0.2;0.775x0.68)
# South Carolina          AxesSubplot(0.125,0.2;0.775x0.68)
# South Dakota            AxesSubplot(0.125,0.2;0.775x0.68)
# Tennessee               AxesSubplot(0.125,0.2;0.775x0.68)
# Texas                   AxesSubplot(0.125,0.2;0.775x0.68)
# Utah                    AxesSubplot(0.125,0.2;0.775x0.68)
# Vermont                 AxesSubplot(0.125,0.2;0.775x0.68)
# Virginia                AxesSubplot(0.125,0.2;0.775x0.68)
# Washington              AxesSubplot(0.125,0.2;0.775x0.68)
# West Virginia           AxesSubplot(0.125,0.2;0.775x0.68)
# Wisconsin               AxesSubplot(0.125,0.2;0.775x0.68)
# Wyoming                 AxesSubplot(0.125,0.2;0.775x0.68)
# Name: ILITOTAL, dtype: object

# %%
df2.groupby(df2.index.week)['ILITOTAL'].sum().plot()

# %%
pivoted = df2.pivot_table(values='ILITOTAL', index=df2.index.day, columns='REGION')

# %%
pivoted
# Out:
# REGION      Alabama      Alaska     Arizona    Arkansas   California  \
# date
# 1        244.200000   48.200000  247.600000   35.600000   597.400000
# 2        226.625000   66.625000  312.250000   37.750000   744.500000
# 3        408.857143   52.142857  362.142857   45.285714   648.714286
# 4        244.800000   26.000000  466.000000   58.400000   872.600000
# 5        962.916667   91.250000  538.583333  181.333333  1306.666667
# 6        124.000000   27.500000  225.500000   25.250000   422.500000
# 7        384.000000   42.600000  380.200000   68.400000   879.600000
# 8        706.400000   55.500000  517.600000   96.800000  1091.500000
# 9        206.125000   64.125000  282.875000   29.000000   690.250000
# 10       410.142857   56.857143  330.428571   60.142857   709.428571
# 11       241.200000   32.200000  349.200000   62.800000   866.600000
# 12       958.583333   99.500000  532.583333  186.833333  1273.083333
# 13       117.250000   24.000000  225.750000   18.250000   415.250000
# 14       207.500000   44.500000  305.250000   29.500000   780.500000
# 15       864.300000   57.500000  490.700000  135.800000  1099.700000
# 16       212.625000   50.500000  307.125000   33.375000   681.500000
# 17       580.000000   53.428571  423.857143   89.857143   834.428571
# 18       203.600000   34.400000  352.800000   54.000000   762.200000
# 19       764.454545  100.909091  549.454545  166.454545  1244.727273
# 20       154.000000   32.000000  255.000000   10.000000   402.000000
# 21       198.500000   36.250000  331.250000   29.250000   732.000000
# 22       926.900000   62.300000  519.400000  133.900000  1060.600000
# 23       207.750000   45.500000  292.125000   24.625000   681.000000
# 24       862.428571   51.714286  398.000000  142.000000   854.000000
# 25       157.800000   38.400000  302.000000   29.800000   702.800000
# 26       673.454545   94.818182  516.545455  126.636364  1140.636364
# 27       199.750000   23.500000  335.000000   11.500000   430.000000
# 28       171.500000   35.000000  307.250000   28.500000   679.250000
# 29       938.400000   55.200000  514.900000  143.600000  1164.800000
# 30       185.625000   35.875000  297.875000   24.625000   713.000000
# 31      1839.000000   85.333333  595.333333  221.000000  1455.333333
#
# REGION    Colorado  Connecticut   Delaware  District of Columbia      Georgia  \
# date
# 1        64.400000    39.000000   6.200000            146.400000   715.400000
# 2        64.875000    65.000000   7.125000            151.875000   925.125000
# 3        71.571429    36.142857   2.714286            164.000000   735.000000
# 4        33.200000    58.600000   9.600000            125.200000   813.600000
# 5       260.916667   158.916667  26.833333            247.833333  1799.916667
# 6        22.250000     8.000000   2.500000             96.500000   381.750000
# 7        61.400000    60.200000   8.800000            130.000000   713.800000
# 8       184.800000    67.800000   8.100000            176.100000  1082.000000
# 9        51.250000    52.125000   3.750000            132.125000   765.250000
# 10       86.571429    53.285714   3.142857            172.142857   766.428571
# 11       37.400000    62.000000  11.600000            154.200000   825.400000
# 12      249.416667   160.750000  28.083333            243.833333  1930.416667
# 13       23.500000     8.500000   1.250000             90.000000   443.500000
# 14       48.250000    35.500000   1.250000            136.000000   779.250000
# 15      208.500000    79.300000  19.800000            189.900000  1201.500000
# 16       47.875000    46.125000   4.250000            120.000000   711.500000
# 17      108.714286    43.285714   2.428571            166.571429   878.714286
# 18       33.800000    39.800000  11.200000             86.200000   726.400000
# 19      148.272727   136.272727  25.727273            232.545455  1731.090909
# 20       24.750000     4.000000   1.250000             88.250000   578.750000
# 21       46.750000    28.250000   2.500000            107.750000   788.000000
# 22      216.900000    98.300000  16.800000            157.100000  1420.500000
# 23       46.625000    46.125000   3.750000            119.625000   700.000000
# 24      121.714286    36.000000   3.857143            164.571429   985.571429
# 25       31.200000    38.000000   9.200000            143.000000   743.600000
# 26      136.909091   133.818182  20.818182            195.363636  1516.454545
# 27       33.500000     5.750000   0.750000            109.250000   626.750000
# 28       39.750000    30.250000   3.000000            148.250000   728.250000
# 29      218.400000   117.900000  20.300000            196.000000  1611.600000
# 30       42.875000    44.125000   1.250000            101.625000   703.000000
# 31      199.000000    68.000000   7.333333            166.666667  1606.000000
#
# REGION     ...      South Dakota   Tennessee        Texas        Utah  \
# date       ...
# 1          ...         63.200000  100.400000   577.400000  251.200000
# 2          ...         96.375000  125.750000   635.250000  168.750000
# 3          ...         77.428571   76.285714   834.714286  194.142857
# 4          ...         74.000000  141.000000   593.600000  314.600000
# 5          ...        223.916667  263.500000  1771.750000  338.416667
# 6          ...         39.500000   59.750000   359.750000  152.250000
# 7          ...         80.600000  158.200000   893.600000  422.800000
# 8          ...        132.700000  170.200000  1139.000000  327.200000
# 9          ...         68.375000   94.875000   582.500000  198.125000
# 10         ...         76.857143  101.428571   947.857143  223.142857
# 11         ...         81.000000  128.200000   559.000000  311.600000
# 12         ...        219.000000  253.166667  1758.166667  370.750000
# 13         ...         37.250000   44.250000   299.250000  158.750000
# 14         ...         59.000000  109.000000   580.000000  214.250000
# 15         ...        147.100000  197.800000  1331.300000  302.300000
# 16         ...         82.125000   79.875000   573.000000  156.625000
# 17         ...         79.857143  129.428571  1214.000000  237.714286
# 18         ...         71.000000   95.600000   516.800000  241.800000
# 19         ...        228.545455  246.272727  1581.090909  437.000000
# 20         ...         40.000000   47.000000   347.750000  131.000000
# 21         ...         51.000000  106.000000   580.500000  217.500000
# 22         ...        166.800000  215.000000  1408.700000  291.500000
# 23         ...         59.500000   98.000000   513.250000  211.250000
# 24         ...         87.857143  137.142857  1368.857143  283.142857
# 25         ...         70.000000  100.600000   465.800000  195.600000
# 26         ...        193.454545  218.363636  1405.363636  398.818182
# 27         ...         39.000000   51.000000   384.250000  105.750000
# 28         ...         55.250000  100.250000   530.250000  211.750000
# 29         ...        176.300000  225.800000  1568.600000  302.100000
# 30         ...         61.000000   79.125000   558.125000  195.250000
# 31         ...        176.666667  223.666667  1448.666667  530.000000
#
# REGION    Vermont     Virginia  Washington  West Virginia   Wisconsin  \
# date
# 1       22.600000  1306.200000   25.200000     134.000000   77.000000
# 2       33.875000  1628.000000   27.750000     167.625000   45.500000
# 3       23.142857  1301.571429   20.857143     114.428571   59.857143
# 4       22.400000  1579.000000   28.400000     158.200000   67.800000
# 5       71.666667  2981.500000   72.750000     352.666667  171.500000
# 6       16.000000   896.500000    9.750000      67.250000   20.000000
# 7       42.200000  2698.200000   23.400000     327.400000  119.800000
# 8       40.900000  2282.300000   69.700000     305.600000  120.600000
# 9       27.125000  1461.375000   21.125000     135.750000   60.500000
# 10      21.000000  1353.571429   20.000000     122.714286   71.571429
# 11      26.600000  1651.000000   22.800000     167.000000   71.000000
# 12      68.916667  3070.750000   59.500000     364.416667  174.166667
# 13      13.750000   816.500000    8.250000      59.750000   26.250000
# 14      20.000000  1011.500000   20.500000     105.500000   75.000000
# 15      44.300000  2152.000000   92.300000     319.500000  133.000000
# 16      25.125000  1254.500000   23.000000     125.125000   60.375000
# 17      28.142857  1565.428571   22.571429     173.000000   96.571429
# 18      24.800000  1591.600000   21.200000     133.000000   46.800000
# 19      59.727273  3243.363636   60.090909     357.272727  151.272727
# 20      11.000000   784.000000    7.750000      57.250000   29.500000
# 21      17.000000  1132.750000   15.000000      84.000000   40.250000
# 22      57.900000  2280.600000   82.800000     359.100000  140.700000
# 23      21.250000  1196.125000   23.625000     110.750000   54.500000
# 24      22.428571  1965.714286   27.285714     217.000000  119.857143
# 25      21.400000  1438.800000   24.000000     115.600000   35.800000
# 26      56.636364  3128.636364   60.363636     322.727273  145.818182
# 27      10.750000   816.250000    7.500000      62.750000   10.000000
# 28       9.500000  1160.000000   14.500000      84.500000   35.500000
# 29      60.900000  2547.800000   84.500000     380.000000  142.200000
# 30      19.750000  1256.875000   22.250000     123.625000   51.750000
# 31      47.000000  5266.333333  108.000000     650.000000  144.666667
#
# REGION     Wyoming
# date
# 1        35.000000
# 2        35.750000
# 3        28.142857
# 4        31.800000
# 5       117.000000
# 6        12.750000
# 7        51.800000
# 8        71.700000
# 9        25.625000
# 10       35.000000
# 11       41.000000
# 12      109.666667
# 13       11.250000
# 14       26.250000
# 15       80.500000
# 16       30.125000
# 17       39.428571
# 18       42.200000
# 19       98.909091
# 20        8.000000
# 21       17.250000
# 22       79.300000
# 23       25.750000
# 24       43.571429
# 25       38.400000
# 26       86.727273
# 27        9.750000
# 28       19.250000
# 29       92.900000
# 30       20.000000
# 31      106.000000
#
# [31 rows x 50 columns]

# %%
pivoted.plot(legend=False)

# %%
df2['ILITOTAL'].resample('D').sum().rolling(4).sum().plot()

# %%
sns.lineplot(x='date', y='ILITOTAL', hue='REGION',data=df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-50d55eea3aa7> in <module>()
# ----> 1 sns.lineplot(x='date', y='ILITOTAL', hue='REGION',data=df2)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1076         dashes=dashes, markers=markers, style_order=style_order,
#    1077         units=units, estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1078         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1079     )
#    1080
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend)
#     661
#     662         plot_data = self.establish_variables(
# --> 663             x, y, hue, size, style, units, data
#     664         )
#     665
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     140                 if isinstance(var, string_types):
#     141                     err = "Could not interpret input '{}'".format(var)
# --> 142                     raise ValueError(err)
#     143
#     144             # Extract variable names
#
# ValueError: Could not interpret input 'date'

# %%
df2.head()

# %%
df2['WEEK'].dt.week()

# %%
df2.resample('ILITOTAL').sum().plot()

# %%
df2.groupby(['WEEK'])['ILITOTAL'].sum().plot()

# %%
# %matplotlib inline
df2.plot()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
test = df2[df2['YEAR'] == 2017]

# %%
test = test[test['WEEK'] == 52]

# %%
counties = alt.topo_feature(data.us_10m.url, 'counties')
unemp_data = data.unemployment.url

# %%
type(counties)

# %%
alt.Chart(test).mark_geoshape().encode(
    color='ILITOTAL:Q'
).project(type='albersUsa')

# %%
test = test[test['WEEK'] == ]

# %%
import altair as alt
from vega_datasets import data

states = alt.topo_feature(data.us_10m.url, 'states')

pop_eng_hur = data.population_engineers_hurricanes.url

variable_list = ['population', 'engineers', 'hurricanes']

alt.Chart(states).mark_geoshape().encode(
    alt.Color(alt.repeat('row'), type='quantitative')
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(pop_eng_hur, 'id', variable_list)
).properties(
    width=500,
    height=300
).project(
    type='albersUsa'
).repeat(
    row=variable_list
).resolve_scale(
    color='independent'
)

# %%
import altair as alt
from vega_datasets import data

counties = alt.topo_feature(data.us_10m.url, 'counties')
unemp_data = data.unemployment.url


alt.Chart(counties).mark_geoshape().encode(
    color='rate:Q'
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(unemp_data, 'id', ['rate'])
).project(
    type='albersUsa'
).properties(
    width=500,
    height=300
)

# %%
df1['ILITOTAL'].str.extract('(\d+)').astype(float)

# %% [markdown]
# # Final Notes
# ![xkcd](https://imgs.xkcd.com/comics/is_it_worth_the_time_2x.png)

# %%
df['Question'].unique().tolist()

# %%
# so what can we do with this "df" data object that we just created?

df. # place cursor after "." and hit "tab" to view options

# %%
# what do all these things do?

 # use "?" after any attribute or function to view the documentation?
df.head?

# %%
# checak out what it looks like using the ".head()" function
df.head()

# %%
df.columns.tolist()

# %%
df.head()

# %%
df['Topic'].unique()

# %%
pd.DataFrame(df.groupby('Topic')['Question'].value_counts())

# %%
df[df['Topic'] == 'Diabetes']['Question'].unique().tolist()

# %%
questions = df['Question'].value_counts()

# %%
q_df = pd.DataFrame(questions)

# %%
q_df

# %%
new_df = df[df['Question'] == 'Mortality due to diabetes reported as any listed cause of death']

# %%
new_df.head()

# %%
alaska_2014 = new_df[(new_df['YearStart'] == 2014) & (new_df['LocationDesc'] == 'Alaska')]

# %%
alaska_2014.shape

# %%
alaska_2014['Stratification1'].nunique()

# %%
alaska_2014[['DataValueType', 'DataValue', 'StratificationCategoryID1', 'Stratification1']]

# %%
# keep only age adjusted values
alaska_2014[alaska_2014['DataValueType'] == 'Age-adjusted Rate'].shape

# %%
alaska_2014.nunique()

# %%
new_df[['DataValueUnit', 'DataValueType', 'DataValue', 'DataValueAlt']]

# %%
new_df['Stratification1'].unique()

# %%
new_df.nunique()

# %%
# extra stuff

# %%
# import the original CDC dataset (large file)
df = pd.read_csv('data/U.S._Chronic_Disease_Indicators__CDI_.csv')

# save main dataset to multiple files
for topic,group_df in df.groupby(pd.Grouper(key='Topic')):
    name = f'data/{topic.lower()}.csv'
    group_df.to_csv(name)
